# %%
from googleapiclient.discovery import build
from google.oauth2 import service_account
from googleapiclient.errors import HttpError
import pandas as pd

# %%
# Allow read/write to the service account's files
SCOPES = ['https://www.googleapis.com/auth/spreadsheets']
SERVICE_ACCOUNT_FILE = "we-need-to-talk-338617-1bfc415b1e1b.json"
creds = service_account.Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
DATA_SHEET_ID = "1_OsK5jXUoQP0JRrfKKwzCxPS936-Qp3fE6RgNR_a82I"

# %%
SHEET_RANGE = "Data!A1:M82"
try:
    service = build('sheets', 'v4', credentials=creds)

    # Call the Sheets API
    sheet = service.spreadsheets()
    result = sheet.values().get(spreadsheetId=DATA_SHEET_ID, range=SHEET_RANGE).execute()
    values = result.get('values', [])

    if not values:
        raise Exception('No data found.')

    for row in values:
        print(row)
except HttpError as err:
    print(err)
# Out:
# ['Province Name', 'Region', 'Phone Prefix', 'Population (2019-2020 Estimate)', 'Health Index Females', 'Income Index Females', 'GDP (Million Lira)', 'GDP Per Capita', 'Mean Household Income', 'Number of Hospitals', 'Number of Visits per Person', 'Number of Menstruators (Estimate)', 'Period Poverty Score']
# ['Adana', 'Mediterranean', '322', '2,237,940', '', '', '62,341', '27,856', '', '', '', '693,761', '0']
# ['Adıyaman', 'Southeastern Anatolia', '416', '626,465', '', '', '11,463', '18,298', '', '', '', '194,204', '0']
# ['Afyonkarahisar', 'Aegean', '272', '729,483', '', '', '18,396', '25,218', '', '', '', '226,140', '0']
# ['Ağrı', 'Eastern Anatolia', '472', '536,199', '', '', '6,864', '12,801', '', '', '', '166,222', '0']
# ['Aksaray', 'Central Anatolia', '382', '416,567', '', '', '10,636', '25,533', '', '', '', '129,136', '0']
# ['Amasya', 'Black Sea', '358', '337,800', '', '', '9,125', '27,013', '', '', '', '104,718', '0']
# ['Ankara', 'Central Anatolia', '312', '5,639,076', '', '', '280,581', '49,757', '', '', '', '1,748,114', '0']
# ['Antalya', 'Mediterranean', '242', '2,511,700', '', '', '90,123', '35,881', '', '', '', '778,627', '0']
# ['Ardahan', 'Eastern Anatolia', '478', '97,319', '', '', '2,276', '23,387', '', '', '', '30,169', '0']
# ['Artvin', 'Black Sea', '466', '170,875', '', '', '5,249', '30,718', '', '', '', '52,971', '0']
# ['Aydın', 'Aegean', '256', '1,110,972', '', '', '30,165', '27,152', '', '', '', '344,401', '0']
# ['Balıkesir', 'Marmara', '266', '1,228,650', '', '', '38,568', '31,391', '', '', '', '380,882', '0']
# ['Bartın', 'Black Sea', '378', '198,249', '', '', '4,668', '23,546', '', '', '', '61,457', '0']
# ['Batman', 'Southeastern Anatolia', '488', '608,659', '', '', '9,845', '16,175', '', '', '', '188,684', '0']
# ['Bayburt', 'Black Sea', '458', '84,843', '', '', '1,812', '21,357', '', '', '', '26,301', '0']
# ['Bilecik', 'Marmara', '228', '219,427', '', '', '9,510', '43,340', '', '', '', '68,022', '0']
# ['Bingöl', 'Eastern Anatolia', '426', '279,812', '', '', '5,213', '18,630', '', '', '', '86,742', '0']
# ['Sinop', 'Black Sea', '368', '218,243', '', '', '4,878', '22,351', '', '', '', '67,655', '0']
# ['Sivas', 'Central Anatolia', '346', '638,956', '', '', '16,588', '25,961', '', '', '', '198,076', '0']
# ['Şırnak', 'Eastern Anatolia', '486', '529,615', '', '', '9,317', '17,592', '', '', '', '164,181', '0']
# ['Tekirdağ', 'Marmara', '282', '1,055,412', '', '', '46,964', '44,498', '', '', '', '327,178', '0']
# ['Tokat', 'Black Sea', '356', '612,747', '', '', '12,151', '19,830', '', '', '', '189,952', '0']
# ['Trabzon', 'Black Sea', '462', '808,974', '', '', '24,103', '29,795', '', '', '', '250,782', '0']
# ['Tunceli', 'Eastern Anatolia', '428', '84,660', '', '', '2,287', '27,014', '', '', '', '26,245', '0']
# ['Uşak', 'Aegean', '276', '370,509', '', '', '13,394', '36,150', '', '', '', '114,858', '0']
# ['Van', 'Eastern Anatolia', '432', '1,136,757', '', '', '15,538', '13,669', '', '', '', '352,395', '0']
# ['Yalova', 'Marmara', '226', '270,976', '', '', '10,379', '38,302', '', '', '', '84,003', '0']
# ['Yozgat', 'Central Anatolia', '354', '421,200', '', '', '9,609', '22,813', '', '', '', '130,572', '0']
# ['Zonguldak', 'Black Sea', '372', '596,053', '', '', '16,520', '27,716', '', '', '', '184,776', '0']

# %%
df = pd.DataFrame(values[1:], columns=values[0])
df
# Out:
#      Province Name                 Region Phone Prefix  \
# 0            Adana          Mediterranean          322
# 1         Adıyaman  Southeastern Anatolia          416
# 2   Afyonkarahisar                 Aegean          272
# 3             Ağrı       Eastern Anatolia          472
# 4          Aksaray       Central Anatolia          382
# ..             ...                    ...          ...
# 76            Uşak                 Aegean          276
# 77             Van       Eastern Anatolia          432
# 78          Yalova                Marmara          226
# 79          Yozgat       Central Anatolia          354
# 80       Zonguldak              Black Sea          372
#
#    Population (2019-2020 Estimate) Health Index Females Income Index Females  \
# 0                        2,237,940
# 1                          626,465
# 2                          729,483
# 3                          536,199
# 4                          416,567
# ..                             ...                  ...                  ...
# 76                         370,509
# 77                       1,136,757
# 78                         270,976
# 79                         421,200
# 80                         596,053
#
#    GDP (Million Lira) GDP Per Capita Mean Household Income  \
# 0              62,341         27,856
# 1              11,463         18,298
# 2              18,396         25,218
# 3               6,864         12,801
# 4              10,636         25,533
# ..                ...            ...                   ...
# 76             13,394         36,150
# 77             15,538         13,669
# 78             10,379         38,302
# 79              9,609         22,813
# 80             16,520         27,716
#
#    Number of Hospitals Number of Visits per Person  \
# 0
# 1
# 2
# 3
# 4
# ..                 ...                         ...
# 76
# 77
# 78
# 79
# 80
#
#    Number of Menstruators (Estimate) Period Poverty Score
# 0                            693,761                    0
# 1                            194,204                    0
# 2                            226,140                    0
# 3                            166,222                    0
# 4                            129,136                    0
# ..                               ...                  ...
# 76                           114,858                    0
# 77                           352,395                    0
# 78                            84,003                    0
# 79                           130,572                    0
# 80                           184,776                    0
#
# [81 rows x 13 columns]
